# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics  
#from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.tree import export_graphviz
from IPython.display import Image  
import pydotplus

# %%
df = pd.read_csv("./data/marketing_campaigns_train.csv", index_col=0)
df.head()
# Out:
#          status  age  n_child education  profession     device  \
# id
# 512491  married   32  unknown  doctoral     student   cellular
# 495633  married   45        1    master   scientist   cellular
# 507946  married   54        2    master  technician  telephone
# 491165  married   30  unknown    master    engineer    unknown
# 494627  married   40  unknown  doctoral     manager    unknown
#
#         account_balance   loan  mortgage  credit  positive campaign_type  \
# id
# 512491              300  False      True   False      True    phone call
# 495633             1339  False      True   False      True    phone call
# 507946             2832  False      True   False      True    phone call
# 491165              530   True      True   False      True    phone call
# 494627             -922   True      True    True     False    phone call
#
#         consent  n_contact  l_date  l_call_duration p_outcome  n_p_contact  \
# id
# 512491    False          2  04-Feb              175   failure            1
# 495633    False          1  08-Jul              322   unknown            0
# 507946    False          1  19-Nov               67   unknown            0
# 491165    False          1  04-Jun               45   unknown            0
# 494627    False          2  23-Jun               39   unknown            0
#
#         p_days  subscribed
# id
# 512491     272       False
# 495633      -1       False
# 507946      -1       False
# 491165      -1       False
# 494627      -1       False

# %%
for col in df:
    if df[col].dtype == 'object':
        df[col] = df[col].astype('category')
        df[col] = df[col].cat.codes
df.head()
# Out:
#         status  age  n_child  education  profession  device  account_balance  \
# id
# 512491       1   32        4          1           7       0              300
# 495633       1   45        1          2           5       0             1339
# 507946       1   54        2          2           9       1             2832
# 491165       1   30        4          2           2       2              530
# 494627       1   40        4          1           3       2             -922
#
#          loan  mortgage  credit  positive  campaign_type  consent  n_contact  \
# id
# 512491  False      True   False      True              0    False          2
# 495633  False      True   False      True              0    False          1
# 507946  False      True   False      True              0    False          1
# 491165   True      True   False      True              0    False          1
# 494627   True      True    True     False              0    False          2
#
#         l_date  l_call_duration  p_outcome  n_p_contact  p_days  subscribed
# id
# 512491      29              175          0            1     272       False
# 495633      72              322          3            0      -1       False
# 507946     194               67          3            0      -1       False
# 491165      31               45          3            0      -1       False
# 494627     227               39          3            0      -1       False

# %%
# df = df.drop(['l_date'], axis=1)
X = df.drop('subscribed', axis=1)
y = df['subscribed']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(random_state=42)

# %%
# Train Decision Tree Classifer 
clf = clf.fit(X_train,y_train)

# %%
# Predict the label
y_pred = clf.predict(X_test)

# %%
print(metrics.accuracy_score(y_test, y_pred))
pd.DataFrame(metrics.confusion_matrix(y_test, y_pred))
# Out:
# 1.0
#       0    1
# 0  6746    0
# 1     0  884

# %%
dot = export_graphviz(clf, filled=True, rounded=True, 
                special_characters=True,feature_names = X.columns,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot)  
graph.write_png('tree1.png')
Image(graph.create_png())
